# %% [markdown]
# # Import packages

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
sys.path.append(os.path.dirname(os.getcwd()))

from common import *

# %% [markdown]
# # 1. Load dataset

# %%
train_data = pd.read_csv(join(PATH.input, "train_data.csv"))
sample_submission = pd.read_csv(join(PATH.input, "sample_submission.csv"))
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3859200 entries, 0 to 3859199
# Data columns (total 13 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   TurbID   int64
#  1   Day      int64
#  2   Tmstamp  object
#  3   Wspd     float64
#  4   Wdir     float64
#  5   Etmp     float64
#  6   Itmp     float64
#  7   Ndir     float64
#  8   Pab1     float64
#  9   Pab2     float64
#  10  Pab3     float64
#  11  Prtv     float64
#  12  Patv     float64
# dtypes: float64(10), int64(2), object(1)
# memory usage: 382.8+ MB

# %% [markdown]
# # 2. Preprocessing

# %% [markdown]
# ## 1) Generate `Time`

# %%
# %%time
train_data = generate_full_timestamp(train_data)
# Out:
# CPU times: user 5.29 s, sys: 80.4 ms, total: 5.37 s
# Wall time: 3.36 s

# %% [markdown]
# ## 2) Imputing

# %%
train_data = impute_data(train_data)
# Out:
# Number of Nan values: 0

# %% [markdown]
# ## 3) Feature engineering

# %%
train_data = preprocess(train_data)

# %%
train_data.drop(columns=['Day', 'Tmstamp'], inplace=True)

# %%
train_data.head()
# Out:
#    TurbID  Wspd  Wdir   Etmp   Itmp   Ndir  Pab1  Pab2  Pab3  Prtv    Patv  Time          X  \
# 0       1  6.17 -3.99  30.73  41.80  25.92   1.0   1.0   1.0 -0.25  494.66     1  3349.8515
# 1       1  6.17 -3.99  30.73  41.80  25.92   1.0   1.0   1.0 -0.25  494.66     2  3349.8515
# 2       1  6.27 -2.18  30.60  41.63  20.91   1.0   1.0   1.0 -0.24  509.76     3  3349.8515
# 3       1  6.42 -0.73  30.52  41.52  20.91   1.0   1.0   1.0 -0.26  542.53     4  3349.8515
# 4       1  6.25  0.89  30.49  41.38  20.91   1.0   1.0   1.0 -0.23  509.36     5  3349.8515
#
#             Y  Time_cos  Time_sin   Day_cos   Day_sin  Etmp_abs  Wdir_adj  Wdir_cos  Wdir_sin  \
# 0  5939.23193  0.999048  0.043619  0.999852  0.017213    273.88     21.93  0.927641  0.373474
# 1  5939.23193  0.999048  0.043619  0.999852  0.017213    273.88     21.93  0.927641  0.373474
# 2  5939.23193  0.996195  0.087156  0.999852  0.017213    273.75     18.73  0.947042  0.321109
# 3  5939.23193  0.991445  0.130526  0.999852  0.017213    273.67     20.18  0.938613  0.344971
# 4  5939.23193  0.984808  0.173648  0.999852  0.017213    273.64     21.80  0.928486  0.371368
#
#    Ndir_cos  Ndir_sin  Wspd_cos  Wspd_sin        RPM   Wspd_cube     P_max
# 0  0.899405  0.437116  6.155045 -0.429323  16.034441  233.181313  0.857621
# 1  0.899405  0.437116  6.155045 -0.429323  16.034441  233.181313  0.857621
# 2  0.934142  0.356901  6.265462 -0.238505  16.322087  245.957079  0.900427
# 3  0.934142  0.356901  6.419479 -0.081794  16.723314  264.544863  0.966892
# 4  0.934142  0.356901  6.249246  0.097080  16.279842  244.052275  0.892196

# %% [markdown]
# ## 3) Split data

# %%
IN_SEQ_LEN  = 5*144
OUT_SEQ_LEN = 2*144
STRIDE      = 1*144
SHUFFLE     = False
TEST_SIZE   = 0.2

# %%
train_x, train_y, val_x, val_y, test_x = make_train_val_test_data(train_data, IN_SEQ_LEN, OUT_SEQ_LEN, STRIDE, SHUFFLE, TEST_SIZE)

train_x = train_x[:, :, 9:10]
val_x   = val_x[:, :, 9:10]
test_x  = test_x[:, :, 9:10]

train_y = train_y[:, :, 9]
val_y   = val_y[:, :, 9]
print("X:", train_x.shape, val_x.shape, test_x.shape)
print("y:", train_y.shape, val_y.shape)
# Out:
# 100%|██████████| 134/134 [00:14<00:00,  9.17it/s]
# Train data(X, y)     : (19832, 720, 28) (19832, 288, 28)
# Validation data(X, y): (4958, 720, 28) (4958, 288, 28)
# Test data(X)         : (134, 720, 28)
# X: (19832, 720, 1) (4958, 720, 1) (134, 720, 1)
# y: (19832, 288) (4958, 288)

# %% [markdown]
# # 3. Modeling

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, LSTM, GRU

tf.keras.utils.set_random_seed(RANDOM_STATE)
for gpu in tf.config.experimental.list_physical_devices('GPU'):
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
train_x[0].shape
# Out:
# (720, 1)

# %%
model = Sequential([
    GRU(256, input_shape=train_x[0].shape),
    Dense(516, activation='relu'),
    Dense(288, activation='relu')
])
optimizer = tf.optimizers.RMSprop(0.001)
model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

# %% [markdown]
# # 4. Training

# %%
from tensorflow.keras.callbacks import EarlyStopping

model.fit(train_x, train_y, validation_data=(val_x, val_y), epochs=1000, batch_size=128, callbacks=[EarlyStopping(patience=10, restore_best_weights=True)]);
# Out:
# Epoch 1/1000
# 155/155 [==============================] - 7s 40ms/step - loss: 217858.6562 - mae: 344.1958 - val_loss: 161384.2031 - val_mae: 305.8539
# Epoch 2/1000
# 155/155 [==============================] - 6s 38ms/step - loss: 193259.4375 - mae: 336.0677 - val_loss: 155057.4062 - val_mae: 273.3385
# Epoch 3/1000
# 155/155 [==============================] - 6s 39ms/step - loss: 186121.6094 - mae: 328.3788 - val_loss: 153104.0469 - val_mae: 287.8761
# Epoch 4/1000
# 155/155 [==============================] - 6s 39ms/step - loss: 179978.4375 - mae: 322.9660 - val_loss: 151551.5938 - val_mae: 280.9527
# Epoch 5/1000
# 155/155 [==============================] - 6s 39ms/step - loss: 170963.0469 - mae: 315.6418 - val_loss: 157863.4844 - val_mae: 302.8687
# Epoch 6/1000
# 155/155 [==============================] - 6s 39ms/step - loss: 161719.7656 - mae: 306.7264 - val_loss: 159599.1562 - val_mae: 303.5716
# Epoch 7/1000
# 155/155 [==============================] - 6s 38ms/step - loss: 155761.6406 - mae: 299.4489 - val_loss: 150435.7812 - val_mae: 290.0506
# Epoch 8/1000
# 155/155 [==============================] - 6s 38ms/step - loss: 151403.3906 - mae: 294.2099 - val_loss: 169235.9688 - val_mae: 320.0488
# Epoch 9/1000
# 155/155 [==============================] - 6s 39ms/step - loss: 147912.6719 - mae: 289.6823 - val_loss: 166087.9375 - val_mae: 313.7916
# Epoch 10/1000
# 155/155 [==============================] - 6s 40ms/step - loss: 144027.6094 - mae: 285.1154 - val_loss: 165070.7188 - val_mae: 310.3296
# Epoch 11/1000
# 155/155 [==============================] - 6s 39ms/step - loss: 140578.9375 - mae: 280.9855 - val_loss: 160012.4375 - val_mae: 300.8931
# Epoch 12/1000
# 155/155 [==============================] - 6s 39ms/step - loss: 136486.3906 - mae: 276.0174 - val_loss: 158716.6406 - val_mae: 300.3956
# Epoch 13/1000
# 155/155 [==============================] - 6s 39ms/step - loss: 132156.1406 - mae: 270.9882 - val_loss: 164335.0156 - val_mae: 308.9394
# Epoch 14/1000
# 155/155 [==============================] - 6s 39ms/step - loss: 128310.8828 - mae: 266.2216 - val_loss: 156609.4219 - val_mae: 294.9684
# Epoch 15/1000
# 155/155 [==============================] - 6s 38ms/step - loss: 125087.5234 - mae: 261.9489 - val_loss: 156172.9531 - val_mae: 292.8719
# Epoch 16/1000
# 155/155 [==============================] - 6s 39ms/step - loss: 121714.4062 - mae: 257.5755 - val_loss: 153299.1406 - val_mae: 286.2531
# Epoch 17/1000
# 155/155 [==============================] - 6s 38ms/step - loss: 117869.5547 - mae: 252.8283 - val_loss: 152313.6562 - val_mae: 293.4278

# %% [markdown]
# # 5. Check validation set

# %%
y_true = val_y
y_pred = model.predict(val_x)
# Out:
# 155/155 [==============================] - 2s 12ms/step

# %%
plt.style.use('ggplot')

fig, axes = plt.subplots(5, 10, figsize=(40, 20))
for i, ax in enumerate(axes.flatten()):  # i: turbID
    y_t = y_true[37*i:37*(i+1)].reshape(-1)[:1000]
    y_p = y_pred[37*i:37*(i+1)].reshape(-1)[:1000]
    ax.plot(y_t, label='true')
    ax.plot(y_p, label='pred')
    ax.legend()

# %% [markdown]
# # 6. Generate submission

# %%
sample_submission['Patv'] = model.predict(test_x).reshape(-1)
sample_submission.to_csv(join(PATH.output, "proposed9.csv"), index=False)
# Out:
# 5/5 [==============================] - 0s 13ms/step
