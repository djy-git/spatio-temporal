# %% [markdown]
# # Import packages

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
sys.path.append(os.path.dirname(os.getcwd()))

from common import *

# %% [markdown]
# # 1. Load dataset

# %%
train_data = pd.read_csv(join(PATH.input, "train_data.csv"))
sample_submission = pd.read_csv(join(PATH.input, "sample_submission.csv"))
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3859200 entries, 0 to 3859199
# Data columns (total 13 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   TurbID   int64
#  1   Day      int64
#  2   Tmstamp  object
#  3   Wspd     float64
#  4   Wdir     float64
#  5   Etmp     float64
#  6   Itmp     float64
#  7   Ndir     float64
#  8   Pab1     float64
#  9   Pab2     float64
#  10  Pab3     float64
#  11  Prtv     float64
#  12  Patv     float64
# dtypes: float64(10), int64(2), object(1)
# memory usage: 382.8+ MB

# %% [markdown]
# # 2. Preprocessing

# %% [markdown]
# ## 1) Generate `Time`

# %%
# %%time
train_data = generate_full_timestamp(train_data)
# Out:
# CPU times: user 9.06 s, sys: 178 ms, total: 9.24 s
# Wall time: 7.21 s

# %% [markdown]
# ## 2) Imputing

# %%
train_data = impute_data(train_data)
# Out:
# Number of Nan values: 0

# %% [markdown]
# ## 3) Feature engineering

# %%
train_data = preprocess(train_data)
train_data.head()
# Out:
#    TurbID  Day  Tmstamp  Wspd  Wdir   Etmp   Itmp   Ndir  Pab1  Pab2  Pab3  Prtv    Patv  Time  \
# 0       1    1        2  6.17 -3.99  30.73  41.80  25.92   1.0   1.0   1.0 -0.25  494.66     1
# 1       1    1        2  6.17 -3.99  30.73  41.80  25.92   1.0   1.0   1.0 -0.25  494.66     2
# 2       1    1        3  6.27 -2.18  30.60  41.63  20.91   1.0   1.0   1.0 -0.24  509.76     3
# 3       1    1        4  6.42 -0.73  30.52  41.52  20.91   1.0   1.0   1.0 -0.26  542.53     4
# 4       1    1        5  6.25  0.89  30.49  41.38  20.91   1.0   1.0   1.0 -0.23  509.36     5
#
#            X           Y  Etmp_abs  Wdir_adj  Wspd_cos  Wspd_sin        RPM     P_max
# 0  3349.8515  5939.23193    273.88     21.93  6.155045 -0.429323  16.034441  0.857621
# 1  3349.8515  5939.23193    273.88     21.93  6.155045 -0.429323  16.034441  0.857621
# 2  3349.8515  5939.23193    273.75     18.73  6.265462 -0.238505  16.322087  0.900427
# 3  3349.8515  5939.23193    273.67     20.18  6.419479 -0.081794  16.723314  0.966892
# 4  3349.8515  5939.23193    273.64     21.80  6.249246  0.097080  16.279842  0.892196

# %%
train_data.drop(columns=['Day', 'Wdir', 'Etmp_abs'], inplace=True)
train_data.head()
# Out:
#    TurbID  Tmstamp  Wspd   Etmp   Itmp   Ndir  Pab1  Pab2  Pab3  Prtv    Patv  Time          X  \
# 0       1        2  6.17  30.73  41.80  25.92   1.0   1.0   1.0 -0.25  494.66     1  3349.8515
# 1       1        2  6.17  30.73  41.80  25.92   1.0   1.0   1.0 -0.25  494.66     2  3349.8515
# 2       1        3  6.27  30.60  41.63  20.91   1.0   1.0   1.0 -0.24  509.76     3  3349.8515
# 3       1        4  6.42  30.52  41.52  20.91   1.0   1.0   1.0 -0.26  542.53     4  3349.8515
# 4       1        5  6.25  30.49  41.38  20.91   1.0   1.0   1.0 -0.23  509.36     5  3349.8515
#
#             Y  Wdir_adj  Wspd_cos  Wspd_sin        RPM     P_max
# 0  5939.23193     21.93  6.155045 -0.429323  16.034441  0.857621
# 1  5939.23193     21.93  6.155045 -0.429323  16.034441  0.857621
# 2  5939.23193     18.73  6.265462 -0.238505  16.322087  0.900427
# 3  5939.23193     20.18  6.419479 -0.081794  16.723314  0.966892
# 4  5939.23193     21.80  6.249246  0.097080  16.279842  0.892196

# %% [markdown]
# ## 3) Split data

# %%
IN_SEQ_LEN  = 2*144
OUT_SEQ_LEN = 2*144
STRIDE      = 1*144
SHUFFLE     = False
TEST_SIZE   = 0.2

# %%
train_x, train_y, val_x, val_y, test_x = make_train_val_test_data(train_data, IN_SEQ_LEN, OUT_SEQ_LEN, STRIDE, SHUFFLE, TEST_SIZE)
# train_y = train_y[:, :, 10]
# val_y   = val_y[:, :, 10]
# print("y:", train_y.shape, val_y.shape)
# Out:
# 100%|██████████| 134/134 [00:13<00:00, 10.10it/s]
# Train data(X, y)     : (20368, 288, 18) (20368, 288, 18)
# Validation data(X, y): (5226, 288, 18) (5226, 288, 18)
# Test data(X)         : (134, 288, 18)

# %% [markdown]
# ## 4) Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
train_x = scaler.fit_transform(train_x.reshape(-1, train_x.shape[-1])).reshape(train_x.shape)
val_x   = scaler.transform(val_x.reshape(-1, val_x.shape[-1])).reshape(val_x.shape)
test_x  = scaler.transform(test_x.reshape(-1, test_x.shape[-1])).reshape(test_x.shape)

# %% [markdown]
# # 3. Modeling

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Input, Dense, LSTM, GRU, Bidirectional, RepeatVector, TimeDistributed, Dropout, BatchNormalization

tf.keras.utils.set_random_seed(RANDOM_STATE)
for gpu in tf.config.experimental.list_physical_devices('GPU'):
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
# model = Sequential([
#     Input(shape=train_x[0].shape),
#     Bidirectional(GRU(256)),
#     RepeatVector(train_x.shape[1]),
#     Bidirectional(GRU(256, return_sequences=True)),
#     Dropout(0.4),
#     TimeDistributed(Dense(18))
# ])
# optimizer = tf.optimizers.Nadam(1e-2)
# model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])
# model.summary()

# print("Input shape:", (None, *train_x[0].shape))
# Out:
# 2022-07-12 16:35:36.408095: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-12 16:35:36.408890: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-12 16:35:36.409163: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-12 16:35:36.409356: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-12 16:35:36.682658: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-12 16:35:36.682803: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-12 16:35:36.682910: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-12 16:35:36.682996: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 19178 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 512)              423936
#  l)
#
#  repeat_vector (RepeatVector  (None, 288, 512)         0
#  )
#
#  bidirectional_1 (Bidirectio  (None, 288, 512)         1182720
#  nal)
#
#  dropout (Dropout)           (None, 288, 512)          0
#
#  time_distributed (TimeDistr  (None, 288, 18)          9234
#  ibuted)
#
# =================================================================
# Total params: 1,615,890
# Trainable params: 1,615,890
# Non-trainable params: 0
# _________________________________________________________________
# Input shape: (None, 288, 18)

# %%
model = Sequential([
    GRU(256, input_shape=train_x[0].shape, return_sequences=True),
    Dropout(0.4),
    GRU(256, input_shape=train_x[0].shape, return_sequences=True),
    
    Dropout(0.4),
    BatchNormalization(),
    Dense(256, activation='relu'),
    
    Dropout(0.4),
    BatchNormalization(),
    Dense(128, activation='relu'),
    
    Dropout(0.4),
    BatchNormalization(),
    Dense(18, activation='relu'),
])
optimizer = tf.optimizers.Nadam(1e-2)
model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])
model.summary()

print("Input shape:", (None, *train_x[0].shape))
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_12 (GRU)                (None, 288, 256)          211968
#
#  dropout_12 (Dropout)        (None, 288, 256)          0
#
#  gru_13 (GRU)                (None, 288, 256)          394752
#
#  dropout_13 (Dropout)        (None, 288, 256)          0
#
#  batch_normalization_3 (Batc  (None, 288, 256)         1024
#  hNormalization)
#
#  dense_15 (Dense)            (None, 288, 256)          65792
#
#  dropout_14 (Dropout)        (None, 288, 256)          0
#
#  batch_normalization_4 (Batc  (None, 288, 256)         1024
#  hNormalization)
#
#  dense_16 (Dense)            (None, 288, 128)          32896
#
#  dropout_15 (Dropout)        (None, 288, 128)          0
#
#  batch_normalization_5 (Batc  (None, 288, 128)         512
#  hNormalization)
#
#  dense_17 (Dense)            (None, 288, 18)           2322
#
# =================================================================
# Total params: 710,290
# Trainable params: 709,010
# Non-trainable params: 1,280
# _________________________________________________________________
# Input shape: (None, 288, 18)

# %% [markdown]
# # 4. Training

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

model.fit(train_x, train_y, validation_data=(val_x, val_y), epochs=1000, batch_size=128,
          callbacks=[
              EarlyStopping(patience=10, restore_best_weights=True),
              ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=3, verbose=1),
          ]);
# Out:
# Epoch 1/1000
# 160/160 [==============================] - 12s 55ms/step - loss: 12962654.0000 - mae: 1175.4286 - val_loss: 35142920.0000 - val_mae: 1868.2279 - lr: 0.0100
# Epoch 2/1000
# 160/160 [==============================] - 8s 50ms/step - loss: 10292774.0000 - mae: 1076.3048 - val_loss: 23668770.0000 - val_mae: 1591.1504 - lr: 0.0100
# Epoch 3/1000
# 160/160 [==============================] - 8s 50ms/step - loss: 6602891.5000 - mae: 901.9838 - val_loss: 11940323.0000 - val_mae: 1218.0901 - lr: 0.0100
# Epoch 4/1000
# 160/160 [==============================] - 8s 50ms/step - loss: 3710585.7500 - mae: 686.2336 - val_loss: 4218573.0000 - val_mae: 815.5676 - lr: 0.0100
# Epoch 5/1000
# 160/160 [==============================] - 8s 49ms/step - loss: 1217995.1250 - mae: 406.6578 - val_loss: 3890314.2500 - val_mae: 700.4755 - lr: 0.0100
# Epoch 6/1000
# 160/160 [==============================] - 8s 50ms/step - loss: 636116.8750 - mae: 307.3697 - val_loss: 2760279.0000 - val_mae: 611.2420 - lr: 0.0100
# Epoch 7/1000
# 160/160 [==============================] - 8s 49ms/step - loss: 502849.5000 - mae: 277.8327 - val_loss: 2183518.2500 - val_mae: 547.7990 - lr: 0.0100
# Epoch 8/1000
# 160/160 [==============================] - 8s 50ms/step - loss: 410445.1250 - mae: 254.3534 - val_loss: 2014151.3750 - val_mae: 496.9899 - lr: 0.0100
# Epoch 9/1000
# 160/160 [==============================] - 8s 51ms/step - loss: 313164.6562 - mae: 223.7498 - val_loss: 1519859.1250 - val_mae: 447.5096 - lr: 0.0100
# Epoch 10/1000
# 160/160 [==============================] - 8s 49ms/step - loss:
1000
# 160/160 [==============================] - 8s 50ms/step - loss: 146867.1406 - mae: 158.2288 - val_loss: 597607.1250 - val_mae: 271.5857 - lr: 0.0048
# Epoch 50/1000
# 160/160 [==============================] - 8s 49ms/step - loss: 146407.1719 - mae: 158.4339 - val_loss: 1098970.8750 - val_mae: 344.4561 - lr: 0.0048
# Epoch 51/1000
# 160/160 [==============================] - 8s 50ms/step - loss: 144272.4844 - mae: 157.3345 - val_loss: 670923.4375 - val_mae: 266.2594 - lr: 0.0048
# Epoch 52/1000
# 160/160 [==============================] - ETA: 0s - loss: 143271.0938 - mae: 157.0764
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.0043046717997640375.
# 160/160 [==============================] - 8s 50ms/step - loss: 143271.0938 - mae: 157.0764 - val_loss: 718149.6875 - val_mae: 273.1517 - lr: 0.0048
# Epoch 53/1000
# 160/160 [==============================] - 8s 49ms/step - loss: 143752.9219 - mae: 157.0962 - val_loss: 922418.1875 - val_mae: 305.8132 - lr: 0.0043
# Epoch 54/1000
# 160/160 [==============================] - 8s 50ms/step - loss: 144477.0156 - mae: 157.2653 - val_loss: 900498.7500 - val_mae: 300.2257 - lr: 0.0043
# Epoch 55/1000
# 160/160 [==============================] - ETA: 0s - loss: 145480.4531 - mae: 157.5552
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.0038742044940590858.
# 160/160 [==============================] - 8s 49ms/step - loss: 145480.4531 - mae: 157.5552 - val_loss: 650168.8750 - val_mae: 273.5964 - lr: 0.0043
# Epoch 56/1000
# 160/160 [==============================] - 8s 49ms/step - loss: 142132.7188 - mae: 156.1406 - val_loss: 673613.0625 - val_mae: 265.3586 - lr: 0.0039
# Epoch 57/1000
# 160/160 [==============================] - 8s 50ms/step - loss: 141131.3281 - mae: 156.0867 - val_loss: 650355.0000 - val_mae: 258.4981 - lr: 0.0039
# Epoch 58/1000
# 160/160 [==============================] - ETA: 0s - loss: 140238.5625 - mae: 155.3829
# Epoch 58: ReduceLROnPlateau reducing learning rate to 0.003486784128472209.
# 160/160 [==============================] - 8s 50ms/step - loss: 140238.5625 - mae: 155.3829 - val_loss: 666943.6875 - val_mae: 263.6155 - lr: 0.0039
# Epoch 59/1000
# 160/160 [==============================] - 8s 50ms/step - loss: 140700.3281 - mae: 155.5703 - val_loss: 725739.7500 - val_mae: 285.4016 - lr: 0.0035

# %% [markdown]
# # 5. Check validation set

# %%
y_true = val_y[:, :, 9]
y_pred = model.predict(val_x)[:, :, 9]
# Out:
# 164/164 [==============================] - 3s 13ms/step

# %%
y_pred[0]
# Out:
# array([471.142, 462.191, 464.833, 464.795, 464.748, 464.609, 464.421, 464.301, 464.255, 464.137,
#        464.071, 464.010, 463.936, 463.888, 463.782, 463.791, 463.738, 463.742, 463.724, 463.747,
#        463.735, 463.788, 463.734, 463.752, 463.826, 463.835, 463.866, 463.880, 463.881, 463.940,
#        463.901, 463.986, 464.037, 464.027, 464.082, 464.131, 464.119, 464.209, 464.219, 464.237,
#        464.322, 464.315, 464.370, 464.405, 464.345, 464.364, 464.396, 464.401, 464.427, 464.433,
#        464.456, 464.468, 464.470, 464.498, 464.537, 464.543, 464.522, 464.524, 464.550, 464.560,
#        464.596, 464.612, 464.612, 464.625, 464.635, 464.652, 464.667, 464.711, 464.718, 464.733,
